# %% [markdown]
# <a href="https://colab.research.google.com/github/wbabury93/Data201-Project-3/blob/main/Project_Number_3_for_Data201_Walid_Babury.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# In my Data I want to compare the arrest records by comparing two boroughs. The Two Boroughs I decided to compare was Queens(Q) and Bronx(B).

# %%
df = pd.DataFrame()

# %%
df= pd.read_csv('https://raw.githubusercontent.com/wbabury93/Data201-Project-3/main/NYPD_Arrest_Data__Year_to_Date_.csv')

# %%
df.count()
# Out:
# ARREST_KEY                  115299
# ARREST_DATE                 115299
# PD_CD                       115278
# PD_DESC                     115238
# KY_CD                       115238
# OFNS_DESC                   115238
# LAW_CODE                    115299
# LAW_CAT_CD                  114221
# ARREST_BORO                 115299
# ARREST_PRECINCT             115299
# JURISDICTION_CODE           115299
# AGE_GROUP                   115299
# PERP_SEX                    115299
# PERP_RACE                   115299
# X_COORD_CD                  115299
# Y_COORD_CD                  115299
# Latitude                    115299
# Longitude                   115299
# New Georeferenced Column    115299
# dtype: int64

# %%
df.tail()
# Out:
#         ARREST_KEY  ...                       New Georeferenced Column
# 115294   222689440  ...   POINT (-73.83112953899997 40.69843969400005)
# 115295   222626401  ...   POINT (-73.84390995399998 40.85580274300003)
# 115296   222477062  ...  POINT (-73.90311219699998 40.870041281000056)
# 115297   222728174  ...   POINT (-73.91536344699995 40.76956124200007)
# 115298   222535613  ...   POINT (-73.94305278599995 40.64412879400004)
#
# [5 rows x 19 columns]

# %%
df.head()
# Out:
#    ARREST_KEY  ...                      New Georeferenced Column
# 0   234233843  ...  POINT (-73.90973778899996 40.82618898100003)
# 1   234129823  ...  POINT (-73.93022154099998 40.67458330800008)
# 2   234040747  ...  POINT (-73.76598558899997 40.60344094100003)
# 3   234047720  ...  POINT (-73.91945797099999 40.83778161800007)
# 4   234042526  ...  POINT (-73.91627635999998 40.83598980000005)
#
# [5 rows x 19 columns]

# %%
df.loc[0:8]
# Out:
#    ARREST_KEY  ...                      New Georeferenced Column
# 0   234233843  ...  POINT (-73.90973778899996 40.82618898100003)
# 1   234129823  ...  POINT (-73.93022154099998 40.67458330800008)
# 2   234040747  ...  POINT (-73.76598558899997 40.60344094100003)
# 3   234047720  ...  POINT (-73.91945797099999 40.83778161800007)
# 4   234042526  ...  POINT (-73.91627635999998 40.83598980000005)
# 5   234006839  ...  POINT (-73.94796350499998 40.79296572700008)
# 6   233952333  ...  POINT (-73.88151172399995 40.67141166300007)
# 7   233878488  ...  POINT (-73.90452841699994 40.81038342800008)
# 8   233784866  ...       POINT (-73.926879392 40.81948754300004)
#
# [9 rows x 19 columns]

# %%
df.drop_duplicates()
# Out:
#         ARREST_KEY  ...                       New Georeferenced Column
# 0        234233843  ...   POINT (-73.90973778899996 40.82618898100003)
# 1        234129823  ...   POINT (-73.93022154099998 40.67458330800008)
# 2        234040747  ...   POINT (-73.76598558899997 40.60344094100003)
# 3        234047720  ...   POINT (-73.91945797099999 40.83778161800007)
# 4        234042526  ...   POINT (-73.91627635999998 40.83598980000005)
# ...            ...  ...                                            ...
# 115294   222689440  ...   POINT (-73.83112953899997 40.69843969400005)
# 115295   222626401  ...   POINT (-73.84390995399998 40.85580274300003)
# 115296   222477062  ...  POINT (-73.90311219699998 40.870041281000056)
# 115297   222728174  ...   POINT (-73.91536344699995 40.76956124200007)
# 115298   222535613  ...   POINT (-73.94305278599995 40.64412879400004)
#
# [115299 rows x 19 columns]

# %%
df.loc[0:7]
# Out:
#    ARREST_KEY  ...                      New Georeferenced Column
# 0   234233843  ...  POINT (-73.90973778899996 40.82618898100003)
# 1   234129823  ...  POINT (-73.93022154099998 40.67458330800008)
# 2   234040747  ...  POINT (-73.76598558899997 40.60344094100003)
# 3   234047720  ...  POINT (-73.91945797099999 40.83778161800007)
# 4   234042526  ...  POINT (-73.91627635999998 40.83598980000005)
# 5   234006839  ...  POINT (-73.94796350499998 40.79296572700008)
# 6   233952333  ...  POINT (-73.88151172399995 40.67141166300007)
# 7   233878488  ...  POINT (-73.90452841699994 40.81038342800008)
#
# [8 rows x 19 columns]

# %%
df.drop(5)
# Out:
#         ARREST_KEY  ...                       New Georeferenced Column
# 0        234233843  ...   POINT (-73.90973778899996 40.82618898100003)
# 1        234129823  ...   POINT (-73.93022154099998 40.67458330800008)
# 2        234040747  ...   POINT (-73.76598558899997 40.60344094100003)
# 3        234047720  ...   POINT (-73.91945797099999 40.83778161800007)
# 4        234042526  ...   POINT (-73.91627635999998 40.83598980000005)
# ...            ...  ...                                            ...
# 115294   222689440  ...   POINT (-73.83112953899997 40.69843969400005)
# 115295   222626401  ...   POINT (-73.84390995399998 40.85580274300003)
# 115296   222477062  ...  POINT (-73.90311219699998 40.870041281000056)
# 115297   222728174  ...   POINT (-73.91536344699995 40.76956124200007)
# 115298   222535613  ...   POINT (-73.94305278599995 40.64412879400004)
#
# [115298 rows x 19 columns]

# %%
df.drop(columns=['ARREST_KEY','PD_CD','KY_CD','LAW_CODE'])
# Out:
#        ARREST_DATE  ...                       New Georeferenced Column
# 0       09/29/2021  ...   POINT (-73.90973778899996 40.82618898100003)
# 1       09/27/2021  ...   POINT (-73.93022154099998 40.67458330800008)
# 2       09/25/2021  ...   POINT (-73.76598558899997 40.60344094100003)
# 3       09/25/2021  ...   POINT (-73.91945797099999 40.83778161800007)
# 4       09/25/2021  ...   POINT (-73.91627635999998 40.83598980000005)
# ...            ...  ...                                            ...
# 115294  01/06/2021  ...   POINT (-73.83112953899997 40.69843969400005)
# 115295  01/05/2021  ...   POINT (-73.84390995399998 40.85580274300003)
# 115296  01/01/2021  ...  POINT (-73.90311219699998 40.870041281000056)
# 115297  01/07/2021  ...   POINT (-73.91536344699995 40.76956124200007)
# 115298  01/03/2021  ...   POINT (-73.94305278599995 40.64412879400004)
#
# [115299 rows x 15 columns]

# %%
df.loc[0:10, ['ARREST_DATE',	'PD_DESC',	'OFNS_DESC',	'LAW_CAT_CD',	'ARREST_BORO',	'ARREST_PRECINCT',	'JURISDICTION_CODE',	'AGE_GROUP',	'PERP_SEX',	'PERP_RACE']]
# Out:
#    ARREST_DATE                         PD_DESC  ... PERP_SEX PERP_RACE
# 0   09/29/2021               STRANGULATION 1ST  ...        M     BLACK
# 1   09/27/2021                          RAPE 1  ...        M     BLACK
# 2   09/25/2021        ASSAULT 2,1,UNCLASSIFIED  ...        M     BLACK
# 3   09/25/2021                       ASSAULT 3  ...        M     BLACK
# 4   09/25/2021                       ASSAULT 3  ...        M     BLACK
# 5   09/24/2021                             NaN  ...        M     BLACK
# 6   09/23/2021  ROBBERY,OPEN AREA UNCLASSIFIED  ...        M     BLACK
# 7   09/21/2021               STRANGULATION 1ST  ...        M     WHITE
# 8   09/19/2021                       ASSAULT 3  ...        F     BLACK
# 9   09/16/2021  ROBBERY,OPEN AREA UNCLASSIFIED  ...        M     BLACK
# 10  09/11/2021                          RAPE 1  ...        M     BLACK
#
# [11 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import numpy

# %%
plt.plot([0,10])

# %% [markdown]
# In my conclusion, I compared the first Ten dataset from 9/11/21-9/29/21. In my dataset I found that more crimes were reported in the Bronx(B) than in Queens during that time period.
